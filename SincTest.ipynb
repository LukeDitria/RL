# %%
import math
import random
import numpy as np
from IPython.display import clear_output
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def adjust_lr(Frame, rate, restart, decay, init_lr):
    #factor = ((Frame//rate) % restart//rate) * decay
    factor = math.asin(Frame)
    #lr = init_lr * (0.1 ** (Frame // 20))
    #lr = init_lr * factor
    return factor

# %%
x = np.linspace(0, 3.14, 41)
np.sinc(x)
plt.plot(np.sinc(x)+0.2)
